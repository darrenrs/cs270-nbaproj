# %% [markdown]
# # Libraries and Parse Data

# %%
import pandas as pd

def spread_df():
  data_df = pd.read_csv('combined_out.csv')
  data_df = data_df.drop('AwayTeam', axis=1)\
                   .drop('HomeTeam', axis=1)\
                   .drop('Date', axis=1)
  data_df = data_df.dropna(axis=0)

  return data_df

spread_df()
# Out:
#       WL_AWAY  MIN_AWAY  PTS_AWAY  FGM_AWAY  FGA_AWAY  FG_PCT_AWAY  FG3M_AWAY
# 3942        L       239        97        39        78        0.500          6  \
# 3943        W       241        95        34        74        0.459          6
# 3944        W       239       117        41        90        0.456          5
# 3945        L       241       103        40        96        0.417          7
# 3946        W       240       104        38        87        0.437         12
# ...       ...       ...       ...       ...       ...          ...        ...
# 23759       L       241       103        38        75        0.507         10
# 23760       W       266       123        38        96        0.396         13
# 23761       L       240       119        43        84        0.512         19
# 23762       W       239       130        43        87        0.494         20
# 23763       W       240       127        45        91        0.495         18
#
#        FG3A_AWAY  FG3_PCT_AWAY  FTM_AWAY  ...  REB_HOME  AST_HOME  STL_HOME
# 3942          13         0.462        13  ...        40        21         8  \
# 3943          22         0.273        21  ...        37        18        16
# 3944          11         0.455        30  ...        37        19         8
# 3945          17         0.412        16  ...        50        31        11
# 3946          23         0.522        16  ...        42        21         5
# ...          ...           ...       ...  ...       ...       ...       ...
# 23759         27         0.370        17  ...        43        22         5
# 23760         44         0.295        34  ...        54        17         3
# 23761         40         0.475        14  ...        41        32         9
# 23762         43         0.465        24  ...        38        26         7
# 23763         44         0.409        19  ...        36        31         7
#
#        BLK_HOME  TOV_HOME  PF_HOME  PLUS_MINUS_HOME  HomeSpread     ELO_AWAY
# 3942          4         8       19              9.0       -13.0  1424.524228  \
# 3943          3        12       22             -2.0         5.0  1569.163161
# 3944          9        20       28            -21.0        -1.0  1582.036310
# 3945         10        15       21             17.0       -11.5  1434.786992
# 3946          6        14       19             -3.0         6.5  1692.182139
# ...         ...       ...      ...              ...         ...          ...
# 23759         4        15       19             10.0        -7.5  1558.570222
# 23760         5        11       28             -2.0        -1.5  1479.170282
# 23761         1        13       14             13.0        -5.0  1462.351755
# 23762         2         5       18            -12.0         8.5  1667.574884
# 23763         2        14       21             -9.0         3.0  1543.281073
#
#           ELO_HOME
# 3942   1686.937878
# 3943   1473.301757
# 3944   1542.257724
# 3945   1555.892358
# 3946   1401.982973
# ...            ...
# 23759  1553.224053
# 23760  1527.940773
# 23761  1592.131809
# 23762  1374.209496
# 23763  1440.323574
#
# [19810 rows x 45 columns]

# %% [markdown]
# # K-Means
